# %% [markdown]
# <a href="https://colab.research.google.com/github/rauanygalio/cnweb_2b2_b/blob/main/cinematica0409.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Formula da Velocidade Média

# %%
def calcVelMedia(deltaS, deltaT):
  velMedia = (deltaS / deltaT)
  return velMedia

# %% [markdown]
# teste de serviço: velocidade media

# %%
print('Velocidade Média: ',calcVelMedia(50, 4))
# Out:
# Velocidade Média:  12.5
